# %% [markdown]
# # AI COUREWORK ROUGH WORK 😁

# %% [markdown]
# ## 1) The below code gets the data for all the data files included within the data set

# %%
import seaborn as snes
import warnings
warnings.filterwarnings("ignore")

f = open("wdbc/wdbc.csv","rt")
wdbc = []
for line in f:
    wdbc.append(line.replace("\n","").replace("\ufeff","").split(","))
f.close()

f = open("wpbc/wpbc.csv","rt")
wpbc = []
for line in f:
    wpbc.append(line.replace("\n","").replace("\ufeff","").split(","))
f.close()

f = open("wdbc/wdbc.csv","rt")
wdbc = []
for line in f:
    wdbc.append(line.replace("\n","").replace("\ufeff","").split(","))
f.close()

f = open("Breast Cancer Wisconsin/BCW.csv","rt")
wdbc = []
for line in f:
    wdbc.append(line.replace("\n","").replace("\ufeff","").split(","))
f.close()

# %% [markdown]
# ## 2) Still trying to get used to using seaborn

# %%
# %matplotlib notebook
dataN = [[],[]]
dataR = [[],[]]
for record in wpbc:
    if record[1] == "N":
        dataN[0].append(float(record[20]))
        dataN[1].append(float(record[21]))
    else:
        dataR[0].append(float(record[20]))
        dataR[1].append(float(record[21]))

snes.regplot(dataN[0],dataN[1], color = "coral")
snes.regplot(dataR[0],dataR[1], color = "lightseagreen")
#LOVELY WARNING SIGNS
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# ## 4) gonna try using dataframes and pandas instead

# %%
# %matplotlib notebook
import pandas as pd
dfWDBC = pd.read_csv("wdbc/wdbc.data")
dfWDBC.head(100)
snes.boxplot(x = dfWDBC["M"], y = dfWDBC["0.3001"], palette = "viridis")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='M', ylabel='0.3001'>

# %% [markdown]
# ## 5 ) So Using Pandas with Seaborn is significantly easier. Only issue we have no way to indicate the names of each label. How can we fix this???

# %%
colHead = ["ID", "B/M", "Radius","Texture",
           "Perimeter","Area","Smoothness","Compactness","Concavity","ConcavePoints","Symmetry","FractalDimension",
          "RadiusSE","TextureSE","PerimeterSE","AreaSE","SmoothnessSE","CompactnessSE","ConcavitySE",
           "ConcavePointsSE","SymmetrySE","FractalDimensionSE","RadiusWorst","TextureWorst",
           "PerimeterWorst","AreaWorst","SmoothnessWorst","CompactnessWorst","ConcavityWorst",
           "ConcavePointsWorst","SymmetryWorst","FractalDimensionWorst"]
dfWDBC = pd.read_csv("wdbc/wdbc.data", header = None)
dfWDBC.columns = colHead
dfWDBC.head(100)
# Out:
#           ID B/M  Radius  Texture  Perimeter    Area  Smoothness  Compactness  \
# 0     842302   M  17.990    10.38     122.80  1001.0     0.11840      0.27760
# 1     842517   M  20.570    17.77     132.90  1326.0     0.08474      0.07864
# 2   84300903   M  19.690    21.25     130.00  1203.0     0.10960      0.15990
# 3   84348301   M  11.420    20.38      77.58   386.1     0.14250      0.28390
# 4   84358402   M  20.290    14.34     135.10  1297.0     0.10030      0.13280
# ..       ...  ..     ...      ...        ...     ...         ...          ...
# 95     86208   M  20.260    23.03     132.40  1264.0     0.09078      0.13130
# 96     86211   B  12.180    17.84      77.79   451.1     0.10450      0.07057
# 97    862261   B   9.787    19.94      62.11   294.5     0.10240      0.05301
# 98    862485   B  11.600    12.84      74.34   412.6     0.08983      0.07525
# 99    862548   M  14.420    19.77      94.48   642.5     0.09752      0.11410
#
# ...

# %% [markdown]
# ## 6) Finally got the dataSet loaded into the correct Format. WOOOO 🔥. Time to experiment with Seaborn

# %%
# %matplotlib notebook
snes.boxplot(x = dfWDBC["B/M"], y = dfWDBC["Radius"],palette = "viridis")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='B/M', ylabel='Radius'>

# %%
# %matplotlib notebook
snes.heatmap(dfWDBC[["Texture",
                     "Area","Compactness","Radius",
                     "ConcavePoints","FractalDimension"]].corr(), cmap = "viridis")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
# %matplotlib notebook
snes.heatmap(dfWDBC.corr(),cmap = "flare")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
# %matplotlib notebook
snes.regplot(dfWDBC.loc[dfWDBC["B/M"] == "M"]["Radius"],dfWDBC.loc[dfWDBC["B/M"] == "M"]["Texture"], color = "lightseagreen")
snes.regplot(dfWDBC.loc[dfWDBC["B/M"] == "B"]["Radius"],dfWDBC.loc[dfWDBC["B/M"] == "B"]["Texture"], color = "coral")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Radius', ylabel='Texture'>

# %% [markdown]
# # END OF TRAIN SESSION 🏁🏁🏁🏁🏁

# %% [markdown]
# ## Lots of progress made. Need to come up with a variety of graphs though. Hopefuly you understand my code lol
